# %%
from transformers import pipeline
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
classifier ("I'm happy to try out BERT")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998406171798706}]

# %%
classifier ("I'm not happy to try out BERT")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9996359348297119}]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Restaurant_Reviews.tsv', delimiter = '\t', quoting = 3)

# %%
df
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
import tensorflow as tf

# %%
classifier = pipeline('sentiment-analysis',model = model,tokenizer = tokenizer)

# %%
sentences = df.Review.values

# %%
y_pred=[]
for i in sentences:
    a = classifier(i)
    y_pred.append(a)

# %%
y_pred
# Out:
# [[{'label': 'POSITIVE', 'score': 0.9998804330825806}],
#  [{'label': 'NEGATIVE', 'score': 0.9997690320014954}],
#  [{'label': 'NEGATIVE', 'score': 0.9996275901794434}],
#  [{'label': 'POSITIVE', 'score': 0.9995303153991699}],
#  [{'label': 'POSITIVE', 'score': 0.9996086955070496}],
#  [{'label': 'NEGATIVE', 'score': 0.992295503616333}],
#  [{'label': 'NEGATIVE', 'score': 0.9909782409667969}],
#  [{'label': 'NEGATIVE', 'score': 0.9024140238761902}],
#  [{'label': 'POSITIVE', 'score': 0.9997226595878601}],
#  [{'label': 'POSITIVE', 'score': 0.9998835325241089}],
#  [{'label': 'POSITIVE', 'score': 0.9962829947471619}],
#  [{'label': 'NEGATIVE', 'score': 0.9978346228599548}],
#  [{'label': 'NEGATIVE', 'score': 0.9997603297233582}],
#  [{'label': 'NEGATIVE', 'score': 0.9762392640113831}],
#  [{'label': 'NEGATIVE', 'score': 0.9994240999221802}],
#  [{'label': 'NEGATIVE', 'score': 0.997475802898407}],
#  [{'label': 'POSITIVE', 'score': 0.9998443126678467}],
#  [{'label': 'NEGATIVE', 'score': 0.9995195865631104}],
#  [{'label': 'NEGATIVE', 'score': 0.999808132648468}],
#  [{'label': 'NEGATIVE', 'score': 0.9966147541999817}],
#  [{'label': 'NEGATIVE', 'score': 0.9966202974319458}],
#  [{'label': 'POSITIVE', 'score': 0.999883770942688}],
#  [{'label': 'POSITIVE', 'score': 0.9998409748077393}],
#  [{'label': 'POSITIVE', 'score': 0.999847412109375}],
#  [{'label': 'POSITIVE', 'score': 0.9980399012565613}],
#  [{'label': 'POSITIVE', 'score': 0.9998683929443359}],
#  [{'label': 'NEGATIVE', 'score': 0.9977879524230957}],
#  [{'label': 'POSITIVE', 'score': 0.9969859719276428}],
#  [{'label': 'NEGATIVE', 'score': 0.9564806818962097}],
#  [{'label': 'NEGATIVE', 'score': 0.999748170375824}],
#  [{'label': 'POSITIVE', 'score': 0.9994682669639587}],
#  [{'label': 'NEGATIVE', 'score': 0.7051593661308289}],
#  [{'label': 'NEGATIVE', 'score': 0.9887582063674927}],
#  [{'label': 'NEGATIVE', 'score': 0.9951981902122498}],
#  [{'label': 'POSITIVE', 'score': 0.9998108744621277}],
#  [{'label': 'NEGATIVE', 'score': 0.9967808723449707}],
#  [{'label': 'POSITIVE', 'score': 0.9998660087585449}],
#  [{'label': 'NEGATIVE', 'score': 0.9997885823249817}],
#  [{'label': 'POSITIVE', 'score': 0.9998588562011719}],
#  [{'label': 'NEGATIVE', 'score': 0.9997518658638}],
#  [{'label': 'POSITIVE', 'score': 0.9983541965484619}],
#  [{'label': 'NEGATIVE', 'score': 0.9997492432594299}],
#  [{'label': 'NEGATIVE', 'score': 0.9944350719451904}],
#  [{'label': 'POSITIVE', 'score': 0.9998077750205994}],
#  [{'label': 'NEGATIVE', 'score': 0.9998090863227844}],
#  [{'label': 'NEGATIVE', 'score': 0.9979433417320251}],
#  [{'label': 'NEGATIVE', 'score': 0.9998272061347961}],
#  [{'label': 'POSITIVE', 'score': 0.9994158744812012}],
#  [{'label': 'NEGATIVE', 'score': 0.9337244033813477}],
#  [{'label': 'POSITIVE', 'score': 0.9998577833175659}],
#  [{'label': 'POSITIVE', 'score': 0.9982411861419678}],
#  [{'label': 'NEGATIVE', 'score': 0.9974502921104431}],
#  [{'label': 'POSITIVE', 'score': 0.9998480081558228}],
#  [{'label': 'NEGATIVE', 'score': 0.9962723255157471}],
#  [{'label': 'POSITIVE', 'score': 0.9992401599884033}],
#  [{'label': 'POSITIVE', 'score': 0.9998899698257446}],
#  [{'label': 'NEGATIVE', 'score': 0.9995951056480408}],
#  [{'label': 'NEGATIVE', 'score': 0.9996910095214844}],
#  [{'label': 'POSITIVE', 'score': 0.9977230429649353}],
#  [{'label': 'NEGATIVE', 'score': 0.987625777721405}],
#  [{'label': 'NEGATIVE', 'score': 0.9825113415718079}],
#  [{'label': 'POSITIVE', 'score': 0.9995835423469543}],
#  [{'label': 'POSITIVE', 'score': 0.9998691082000732}],
#  [{'label': 'POSITIVE', 'score': 0.9995185136795044}],
#  [{'label': 'POSITIVE', 'score': 0.999725878238678}],
#  [{'label': 'POSITIVE', 'score': 0.9998505115509033}],
#  [{'label': 'POSITIVE', 'score': 0.9998533725738525}],
#  [{'label': 'POSITIVE', 'score': 0.9998651742935181}],
#  [{'label': 'NEGATIVE', 'score': 0.9650346636772156}],
#  [{'label': 'POSITIVE', 'score': 0.9998794794082642}],
#  [{'label': 'POSITIVE', 'score': 0.999075174331665}],
#  [{'label': 'POSITIVE', 'score': 0.9998168349266052}],
#  [{'label': 'NEGATIVE', 'score': 0.9819774031639099}],
#  [{'label': 'NEGATIVE', 'score': 0.9983522891998291}],
#  [{'label': 'NEGATIVE', 'score': 0.9970406889915466}],
#  [{'label': 'NEGATIVE', 'score': 0.9970842003822327}],
#  [{'label': 'NEGATIVE', 'score': 0.9997798800468445}],
#  [{'label': 'POSITIVE', 'score': 0.9997523427009583}],
#  [{'label': 'POSITIVE', 'score': 0.9998348951339722}],
#  [{'label': 'POSITIVE', 'score': 0.6817055940628052}],
#  [{'label': 'NEGATIVE', 'score': 0.9899469017982483}],
#  [{'label': 'NEGATIVE', 'score': 0.9989122152328491}],
#  [{'label': 'NEGATIVE', 'score': 0.9997518658638}],
#  [{'label': 'POSITIVE', 'score': 0.9997056126594543}],
#  [{'label': 'NEGATIVE', 'score': 0.9997401833534241}],
#  [{'label': 'POSITIVE', 'score': 0.9995662569999695}],
#  [{'label': 'NEGATIVE', 'score': 0.9994489550590515}],
#  [{'label': 'POSITIVE', 'score': 0.9998453855514526}],
#  [{'label': 'POSITIVE', 'score': 0.9991530179977417}],
#  [{'label': 'POSITIVE', 'score': 0.999887228012085}],
#  [{'label': 'NEGATIVE', 'score': 0.9996490478515625}],
#  [{'label': 'POSITIVE', 'score': 0.9965392351150513}],
#  [{'label': 'POSITIVE', 'score': 0.9954931735992432}],
#  [{'label': 'POSITIVE', 'score': 0.999821126461029}],
#  [{'label': 'POSITIVE', 'score': 0.9997251629829407}],
#  [{'label': 'POSITIVE', 'score': 0.6947008371353149}],
#  [{'label': 'POSITIVE', 'score': 0.9993377327919006}],
#  [{'label': 'POSITIVE', 'score': 0.998977780342102}],
#  [{'label': 'NEGATIVE', 'score': 0.9997754693031311}],
#  [{'label': 'POSITIVE', 'score': 0.9998327493667603}],
#  [{'label': 'POSITIVE', 'score': 0.9991781115531921}],
#  [{'label': 'NEGATIVE', 'score': 0.9300515055656433}],
#  [{'label': 'POSITIVE', 'score': 0.9973397850990295}],
#  [{'label': 'POSITIVE', 'score': 0.9998477697372437}],
#  [{'label': 'POSITIVE', 'score': 0.9965412020683289}],
#  [{'label': 'POSITIVE', 'score': 0.9998611211776733}],
#  [{'label': 'POSITIVE', 'score': 0.999885082244873}],
#  [{'label': 'POSITIVE', 'score': 0.9998859167098999}],
#  [{'label': 'POSITIVE', 'score': 0.9863970875740051}],
#  [{'label': 'POSITIVE', 'score': 0.9998540878295898}],
#  [{'label': 'NEGATIVE', 'score': 0.9993302822113037}],
#  [{'label': 'NEGATIVE', 'score': 0.9787405133247375}],
#  [{'label': 'POSITIVE', 'score': 0.9998724460601807}],
#  [{'label': 'POSITIVE', 'score': 0.999879002571106}],
#  [{'label': 'POSITIVE', 'score': 0.9998422861099243}],
#  [{'label': 'POSITIVE', 'score': 0.9997097849845886}],
#  [{'label': 'NEGATIVE', 'score': 0.9997860789299011}],
#  [{'label': 'NEGATIVE', 'score': 0.9945255517959595}],
#  [{'label': 'POSITIVE', 'score': 0.9856777787208557}],
#  [{'label': 'NEGATIVE', 'score': 0.9996979236602783}],
#  [{'label': 'NEGATIVE', 'score': 0.9990707635879517}],
#  [{'label': 'NEGATIVE', 'score': 0.9991227984428406}],
#  [{'label': 'POSITIVE', 'score': 0.9997891783714294}],
#  [{'label': 'POSITIVE', 'score': 0.9983419179916382}],
#  [{'label': 'POSITIVE', 'score': 0.9985519051551819}],
#  [{'label': 'NEGATIVE', 'score': 0.9991993308067322}],
#  [{'label': 'NEGATIVE', 'score': 0.9745080471038818}],
#  [{'label': 'POSITIVE', 'score': 0.9998877048492432}],
#  [{'label': 'NEGATIVE', 'score': 0.9966720342636108}],
#  [{'label': 'POSITIVE', 'score': 0.998370349407196}],
#  [{'label': 'NEGATIVE', 'score': 0.9996800422668457}],
#  [{'label': 'POSITIVE', 'score': 0.9992282390594482}],
#  [{'label': 'POSITIVE', 'score': 0.9996955394744873}],
#  [{'label': 'NEGATIVE', 'score': 0.9995582699775696}],
#  [{'label': 'POSITIVE', 'score': 0.9998032450675964}],
#  [{'label': 'POSITIVE', 'score': 0.9990800619125366}],
#  [{'label': 'POSITIVE', 'score': 0.9998600482940674}],
#  [{'label': 'POSITIVE', 'score': 0.9998385906219482}],
#  [{'label': 'NEGATIVE', 'score': 0.9336095452308655}],
#  [{'label': 'POSITIVE', 'score': 0.9998082518577576}],
#  [{'label': 'NEGATIVE', 'score': 0.9991912245750427}],
#  [{'label': 'NEGATIVE', 'score': 0.9952324032783508}],
#  [{'label': 'NEGATIVE', 'score': 0.9994915723800659}],
#  [{'label': 'NEGATIVE', 'score': 0.9996572732925415}],
#  [{'label': 'NEGATIVE', 'score': 0.9979405999183655}],
#  [{'label': 'POSITIVE', 'score': 0.9997971653938293}],
#  [{'label': 'NEGATIVE', 'score': 0.9997419714927673}],
#  [{'label': 'NEGATIVE', 'score': 0.9996944665908813}],
#  [{'label': 'NEGATIVE', 'score': 0.9891071915626526}],
#  [{'label': 'NEGATIVE', 'score': 0.9996398687362671}],
#  [{'label': 'POSITIVE', 'score': 0.9997825026512146}],
#  [{'label': 'POSITIVE', 'score': 0.9997631907463074}],
#  [{'label': 'NEGATIVE', 'score': 0.9987013339996338}],
#  [{'label': 'NEGATIVE', 'score': 0.9997749924659729}],
#  [{'label': 'POSITIVE', 'score': 0.9998416900634766}],
#  [{'label': 'POSITIVE', 'score': 0.9997145533561707}],
#  [{'label': 'POSITIVE', 'score': 0.9998828172683716}],
#  [{'label': 'POSITIVE', 'score': 0.9986194372177124}],
#  [{'label': 'POSITIVE', 'score': 0.9998615980148315}],
#  [{'label': 'NEGATIVE', 'score': 0.999788224697113}],
#  [{'label': 'NEGATIVE', 'score': 0.99498450756073}],
#  [{'label': 'POSITIVE', 'score': 0.9989233613014221}],
#  [{'label': 'POSITIVE', 'score': 0.9994844198226929}],
#  [{'label': 'NEGATIVE', 'score': 0.9957268238067627}],
#  [{'label': 'POSITIVE', 'score': 0.9974719882011414}],
#  [{'label': 'POSITIVE', 'score': 0.9998800754547119}],
#  [{'label': 'POSITIVE', 'score': 0.9995782971382141}],
#  [{'label': 'NEGATIVE', 'score': 0.9988064765930176}],
#  [{'label': 'POSITIVE', 'score': 0.9980691075325012}],
#  [{'label': 'NEGATIVE', 'score': 0.9810985922813416}],
#  [{'label': 'NEGATIVE', 'score': 0.9998077750205994}],
#  [{'label': 'NEGATIVE', 'score': 0.6259833574295044}],
#  [{'label': 'POSITIVE', 'score': 0.9997779726982117}],
#  [{'label': 'POSITIVE', 'score': 0.999299168586731}],
#  [{'label': 'POSITIVE', 'score': 0.9998713731765747}],
#  [{'label': 'NEGATIVE', 'score': 0.9958958625793457}],
#  [{'label': 'NEGATIVE', 'score': 0.999700665473938}],
#  [{'label': 'POSITIVE', 'score': 0.9995933175086975}],
#  [{'label': 'POSITIVE', 'score': 0.9960247278213501}],
#  [{'label': 'NEGATIVE', 'score': 0.9954608082771301}],
#  [{'label': 'NEGATIVE', 'score': 0.9998055100440979}],
#  [{'label': 'NEGATIVE', 'score': 0.9991476535797119}],
#  [{'label': 'NEGATIVE', 'score': 0.9907062649726868}],
#  [{'label': 'NEGATIVE', 'score': 0.999413013458252}],
#  [{'label': 'POSITIVE', 'score': 0.9998537302017212}],
#  [{'label': 'POSITIVE', 'score': 0.9998311996459961}],
#  [{'label': 'NEGATIVE', 'score': 0.9990825653076172}],
#  [{'label': 'POSITIVE', 'score': 0.9998437166213989}],
#  [{'label': 'POSITIVE', 'score': 0.984038233757019}],
#  [{'label': 'POSITIVE', 'score': 0.9998412132263184}],
#  [{'label': 'POSITIVE', 'score': 0.9997887015342712}],
#  [{'label': 'POSITIVE', 'score': 0.9998666048049927}],
#  [{'label': 'NEGATIVE', 'score': 0.9996926784515381}],
#  [{'label': 'POSITIVE', 'score': 0.9982445240020752}],
#  [{'label': 'POSITIVE', 'score': 0.9961482286453247}],
#  [{'label': 'POSITIVE', 'score': 0.999537467956543}],
#  [{'label': 'POSITIVE', 'score': 0.9834256768226624}],
#  [{'label': 'NEGATIVE', 'score': 0.9433387517929077}],
#  [{'label': 'POSITIVE', 'score': 0.9998552799224854}],
#  [{'label': 'POSITIVE', 'score': 0.99985671043396}],
#  [{'label': 'POSITIVE', 'score': 0.9990148544311523}],
#  [{'label': 'POSITIVE', 'score': 0.999000608921051}],
#  [{'label': 'NEGATIVE', 'score': 0.6074996590614319}],
#  [{'label': 'POSITIVE', 'score': 0.9969047904014587}],
#  [{'label': 'POSITIVE', 'score': 0.9998657703399658}],
#  [{'label': 'POSITIVE', 'score': 0.9998733997344971}],
#  [{'label': 'POSITIVE', 'score': 0.9964666366577148}],
#  [{'label': 'NEGATIVE', 'score': 0.9997859597206116}],
#  [{'label': 'NEGATIVE', 'score': 0.9966785907745361}],
#  [{'label': 'NEGATIVE', 'score': 0.9860984086990356}],
#  [{'label': 'NEGATIVE', 'score': 0.9990794658660889}],
#  [{'label': 'NEGATIVE', 'score': 0.9963120818138123}],
#  [{'label': 'POSITIVE', 'score': 0.9991550445556641}],
#  [{'label': 'NEGATIVE', 'score': 0.9637708067893982}],
#  [{'label': 'POSITIVE', 'score': 0.9998874664306641}],
#  [{'label': 'POSITIVE', 'score': 0.9998040795326233}],
#  [{'label': 'NEGATIVE', 'score': 0.9997978806495667}],
#  [{'label': 'POSITIVE', 'score': 0.9998672008514404}],
#  [{'label': 'NEGATIVE', 'score': 0.9997336268424988}],
#  [{'label': 'POSITIVE', 'score': 0.9997202754020691}],
#  [{'label': 'NEGATIVE', 'score': 0.9695091247558594}],
#  [{'label': 'NEGATIVE', 'score': 0.9997841715812683}],
#  [{'label': 'NEGATIVE', 'score': 0.9986085295677185}],
#  [{'label': 'POSITIVE', 'score': 0.818366527557373}],
#  [{'label': 'NEGATIVE', 'score': 0.9997797608375549}],
#  [{'label': 'POSITIVE', 'score': 0.9997037053108215}],
#  [{'label': 'NEGATIVE', 'score': 0.9907764792442322}],
#  [{'label': 'POSITIVE', 'score': 0.9998821020126343}],
#  [{'label': 'NEGATIVE', 'score': 0.9996328353881836}],
#  [{'label': 'POSITIVE', 'score': 0.9998548030853271}],
#  [{'label': 'POSITIVE', 'score': 0.9998784065246582}],
#  [{'label': 'NEGATIVE', 'score': 0.9868159890174866}],
#  [{'label': 'POSITIVE', 'score': 0.99986732006073}],
#  [{'label': 'NEGATIVE', 'score': 0.9995062351226807}],
#  [{'label': 'POSITIVE', 'score': 0.9989547729492188}],
#  [{'label': 'NEGATIVE', 'score': 0.9977568984031677}],
#  [{'label': 'NEGATIVE', 'score': 0.998781144618988}],
#  [{'label': 'NEGATIVE', 'score': 0.6970434784889221}],
#  [{'label': 'NEGATIVE', 'score': 0.9992601275444031}],
#  [{'label': 'POSITIVE', 'score': 0.9998461008071899}],
#  [{'label': 'NEGATIVE', 'score': 0.9828776121139526}],
#  [{'label': 'POSITIVE', 'score': 0.999305248260498}],
#  [{'label': 'NEGATIVE', 'score': 0.9997413754463196}],
#  [{'label': 'NEGATIVE', 'score': 0.9991382360458374}],
#  [{'label': 'NEGATIVE', 'score': 0.9541696310043335}],
#  [{'label': 'NEGATIVE', 'score': 0.9948577880859375}],
#  [{'label': 'POSITIVE', 'score': 0.9998874664306641}],
#  [{'label': 'POSITIVE', 'score': 0.9984166622161865}],
#  [{'label': 'NEGATIVE', 'score': 0.9581052660942078}],
#  [{'label': 'NEGATIVE', 'score': 0.9961540102958679}],
#  [{'label': 'POSITIVE', 'score': 0.9998732805252075}],
#  [{'label': 'NEGATIVE', 'score': 0.9820533990859985}],
#  [{'label': 'POSITIVE', 'score': 0.9997904896736145}],
#  [{'label': 'NEGATIVE', 'score': 0.9950267672538757}],
#  [{'label': 'POSITIVE', 'score': 0.9996641874313354}],
#  [{'label': 'POSITIVE', 'score': 0.9974262118339539}],
#  [{'label': 'POSITIVE', 'score': 0.9998663663864136}],
#  [{'label': 'NEGATIVE', 'score': 0.9994974136352539}],
#  [{'label': 'POSITIVE', 'score': 0.9996887445449829}],
#  [{'label': 'NEGATIVE', 'score': 0.9939256310462952}],
#  [{'label': 'POSITIVE', 'score': 0.996880054473877}],
#  [{'label': 'NEGATIVE', 'score': 0.9845311641693115}],
#  [{'label': 'POSITIVE', 'score': 0.9998607635498047}],
#  [{'label': 'POSITIVE', 'score': 0.9998107552528381}],
#  [{'label': 'POSITIVE', 'score': 0.9998291730880737}],
#  [{'label': 'NEGATIVE', 'score': 0.9961697459220886}],
#  [{'label': 'NEGATIVE', 'score': 0.9990960359573364}],
#  [{'label': 'POSITIVE', 'score': 0.9998390674591064}],
#  [{'label': 'POSITIVE', 'score': 0.9998493194580078}],
#  [{'label': 'NEGATIVE', 'score': 0.9997066855430603}],
#  [{'label': 'POSITIVE', 'score': 0.5944168567657471}],
#  [{'label': 'NEGATIVE', 'score': 0.9855477809906006}],
#  [{'label': 'NEGATIVE', 'score': 0.9964935183525085}],
#  [{'label': 'POSITIVE', 'score': 0.9820908904075623}],
#  [{'label': 'POSITIVE', 'score': 0.9998551607131958}],
#  [{'label': 'NEGATIVE', 'score': 0.9900740385055542}],
#  [{'label': 'POSITIVE', 'score': 0.999876856803894}],
#  [{'label': 'POSITIVE', 'score': 0.9988942742347717}],
#  [{'label': 'NEGATIVE', 'score': 0.9893547296524048}],
#  [{'label': 'NEGATIVE', 'score': 0.9996664524078369}],
#  [{'label': 'POSITIVE', 'score': 0.9971899390220642}],
#  [{'label': 'NEGATIVE', 'score': 0.999707043170929}],
#  [{'label': 'NEGATIVE', 'score': 0.976778507232666}],
#  [{'label': 'NEGATIVE', 'score': 0.9996789693832397}],
#  [{'label': 'POSITIVE', 'score': 0.999539852142334}],
#  [{'label': 'POSITIVE', 'score': 0.9998296499252319}],
#  [{'label': 'NEGATIVE', 'score': 0.9991840720176697}],
#  [{'label': 'NEGATIVE', 'score': 0.9993683695793152}],
#  [{'label': 'POSITIVE', 'score': 0.9998842477798462}],
#  [{'label': 'NEGATIVE', 'score': 0.9994785189628601}],
#  [{'label': 'NEGATIVE', 'score': 0.9982239603996277}],
#  [{'label': 'NEGATIVE', 'score': 0.9989687204360962}],
#  [{'label': 'POSITIVE', 'score': 0.9998443126678467}],
#  [{'label': 'NEGATIVE', 'score': 0.9675230979919434}],
#  [{'label': 'POSITIVE', 'score': 0.9427741169929504}],
#  [{'label': 'POSITIVE', 'score': 0.9971019625663757}],
#  [{'label': 'NEGATIVE', 'score': 0.9980303645133972}],
#  [{'label': 'POSITIVE', 'score': 0.9998772144317627}],
#  [{'label': 'POSITIVE', 'score': 0.9985646605491638}],
#  [{'label': 'POSITIVE', 'score': 0.9998666048049927}],
#  [{'label': 'POSITIVE', 'score': 0.9998476505279541}],
#  [{'label': 'NEGATIVE', 'score': 0.9884676337242126}],
#  [{'label': 'NEGATIVE', 'score': 0.9997212290763855}],
#  [{'label': 'NEGATIVE', 'score': 0.9996042847633362}],
#  [{'label': 'POSITIVE', 'score': 0.9996957778930664}],
#  [{'label': 'NEGATIVE', 'score': 0.9902631044387817}],
#  [{'label': 'NEGATIVE', 'score': 0.9838848114013672}],
#  [{'label': 'NEGATIVE', 'score': 0.9995146989822388}],
#  [{'label': 'POSITIVE', 'score': 0.9998847246170044}],
#  [{'label': 'POSITIVE', 'score': 0.9560339450836182}],
#  [{'label': 'POSITIVE', 'score': 0.9998823404312134}],
#  [{'label': 'POSITIVE', 'score': 0.9841760993003845}],
#  [{'label': 'POSITIVE', 'score': 0.9998637437820435}],
#  [{'label': 'NEGATIVE', 'score': 0.9824491739273071}],
#  [{'label': 'POSITIVE', 'score': 0.9998000264167786}],
#  [{'label': 'NEGATIVE', 'score': 0.9995976090431213}],
#  [{'label': 'NEGATIVE', 'score': 0.8946583867073059}],
#  [{'label': 'POSITIVE', 'score': 0.9841530919075012}],
#  [{'label': 'POSITIVE', 'score': 0.9985188841819763}],
#  [{'label': 'POSITIVE', 'score': 0.7079586982727051}],
#  [{'label': 'NEGATIVE', 'score': 0.998781144618988}],
#  [{'label': 'NEGATIVE', 'score': 0.9993718266487122}],
#  [{'label': 'POSITIVE', 'score': 0.999847412109375}],
#  [{'label': 'POSITIVE', 'score': 0.9998757839202881}],
#  [{'label': 'POSITIVE', 'score': 0.9874135255813599}],
#  [{'label': 'NEGATIVE', 'score': 0.9985297918319702}],
#  [{'label': 'POSITIVE', 'score': 0.9993714690208435}],
#  [{'label': 'POSITIVE', 'score': 0.9996964931488037}],
#  [{'label': 'NEGATIVE', 'score': 0.9973378777503967}],
#  [{'label': 'NEGATIVE', 'score': 0.99886155128479}],
#  [{'label': 'NEGATIVE', 'score': 0.9997655749320984}],
#  [{'label': 'POSITIVE', 'score': 0.9998574256896973}],
#  [{'label': 'POSITIVE', 'score': 0.9998824596405029}],
#  [{'label': 'NEGATIVE', 'score': 0.9998016953468323}],
#  [{'label': 'POSITIVE', 'score': 0.9998842477798462}],
#  [{'label': 'POSITIVE', 'score': 0.9998841285705566}],
#  [{'label': 'NEGATIVE', 'score': 0.9904166460037231}],
#  [{'label': 'NEGATIVE', 'score': 0.9994884729385376}],
#  [{'label': 'NEGATIVE', 'score': 0.9784843325614929}],
#  [{'label': 'NEGATIVE', 'score': 0.9996591806411743}],
#  [{'label': 'NEGATIVE', 'score': 0.9996441602706909}],
#  [{'label': 'POSITIVE', 'score': 0.9997774958610535}],
#  [{'label': 'POSITIVE', 'score': 0.9986506104469299}],
#  [{'label': 'POSITIVE', 'score': 0.9997362494468689}],
#  [{'label': 'NEGATIVE', 'score': 0.9997794032096863}],
#  [{'label': 'POSITIVE', 'score': 0.9998332262039185}],
#  [{'label': 'POSITIVE', 'score': 0.8846131563186646}],
#  [{'label': 'POSITIVE', 'score': 0.9998088479042053}],
#  [{'label': 'POSITIVE', 'score': 0.9631291031837463}],
#  [{'label': 'POSITIVE', 'score': 0.9998030066490173}],
#  [{'label': 'NEGATIVE', 'score': 0.9994363188743591}],
#  [{'label': 'NEGATIVE', 'score': 0.9994938373565674}],
#  [{'label': 'POSITIVE', 'score': 0.9991618394851685}],
#  [{'label': 'NEGATIVE', 'score': 0.9777277708053589}],
#  [{'label': 'POSITIVE', 'score': 0.9998835325241089}],
#  [{'label': 'POSITIVE', 'score': 0.9998857975006104}],
#  [{'label': 'NEGATIVE', 'score': 0.9992120265960693}],
#  [{'label': 'POSITIVE', 'score': 0.9998902082443237}],
#  [{'label': 'POSITIVE', 'score': 0.999785840511322}],
#  [{'label': 'POSITIVE', 'score': 0.9998103976249695}],
#  [{'label': 'NEGATIVE', 'score': 0.9996774196624756}],
#  [{'label': 'POSITIVE', 'score': 0.9998834133148193}],
#  [{'label': 'POSITIVE', 'score': 0.9998370409011841}],
#  [{'label': 'NEGATIVE', 'score': 0.9563153386116028}],
#  [{'label': 'POSITIVE', 'score': 0.9990134239196777}],
#  [{'label': 'NEGATIVE', 'score': 0.9995326995849609}],
#  [{'label': 'NEGATIVE', 'score': 0.9993196725845337}],
#  [{'label': 'NEGATIVE', 'score': 0.9723458886146545}],
#  [{'label': 'POSITIVE', 'score': 0.9998855590820312}],
#  [{'label': 'POSITIVE', 'score': 0.9971053004264832}],
#  [{'label': 'NEGATIVE', 'score': 0.9997338652610779}],
#  [{'label': 'NEGATIVE', 'score': 0.93837571144104}],
#  [{'label': 'POSITIVE', 'score': 0.9998654127120972}],
#  [{'label': 'POSITIVE', 'score': 0.999734103679657}],
#  [{'label': 'NEGATIVE', 'score': 0.9995229244232178}],
#  [{'label': 'POSITIVE', 'score': 0.9996559619903564}],
#  [{'label': 'NEGATIVE', 'score': 0.9709251523017883}],
#  [{'label': 'POSITIVE', 'score': 0.9998880624771118}],
#  [{'label': 'NEGATIVE', 'score': 0.9994598031044006}],
#  [{'label': 'NEGATIVE', 'score': 0.9997304081916809}],
#  [{'label': 'NEGATIVE', 'score': 0.9928883910179138}],
#  [{'label': 'POSITIVE', 'score': 0.9998630285263062}],
#  [{'label': 'NEGATIVE', 'score': 0.9817177057266235}],
#  [{'label': 'NEGATIVE', 'score': 0.9991908669471741}],
#  [{'label': 'NEGATIVE', 'score': 0.7547832131385803}],
#  [{'label': 'NEGATIVE', 'score': 0.9988195300102234}],
#  [{'label': 'POSITIVE', 'score': 0.9990290403366089}],
#  [{'label': 'NEGATIVE', 'score': 0.9711889028549194}],
#  [{'label': 'NEGATIVE', 'score': 0.9997891783714294}],
#  [{'label': 'POSITIVE', 'score': 0.9226490259170532}],
#  [{'label': 'POSITIVE', 'score': 0.8908548951148987}],
#  [{'label': 'POSITIVE', 'score': 0.9997891783714294}],
#  [{'label': 'POSITIVE', 'score': 0.9998519420623779}],
#  [{'label': 'POSITIVE', 'score': 0.9989191293716431}],
#  [{'label': 'POSITIVE', 'score': 0.9994920492172241}],
#  [{'label': 'NEGATIVE', 'score': 0.9885550141334534}],
#  [{'label': 'NEGATIVE', 'score': 0.9414577484130859}],
#  [{'label': 'POSITIVE', 'score': 0.9983431100845337}],
#  [{'label': 'POSITIVE', 'score': 0.9998791217803955}],
#  [{'label': 'POSITIVE', 'score': 0.9998581409454346}],
#  [{'label': 'NEGATIVE', 'score': 0.9998170733451843}],
#  [{'label': 'NEGATIVE', 'score': 0.9997292160987854}],
#  [{'label': 'NEGATIVE', 'score': 0.9954699277877808}],
#  [{'label': 'POSITIVE', 'score': 0.9998791217803955}],
#  [{'label': 'POSITIVE', 'score': 0.9954755902290344}],
#  [{'label': 'NEGATIVE', 'score': 0.9997865557670593}],
#  [{'label': 'POSITIVE', 'score': 0.9995230436325073}],
#  [{'label': 'POSITIVE', 'score': 0.9949157238006592}],
#  [{'label': 'POSITIVE', 'score': 0.9998712539672852}],
#  [{'label': 'NEGATIVE', 'score': 0.9997746348381042}],
#  [{'label': 'POSITIVE', 'score': 0.999742329120636}],
#  [{'label': 'POSITIVE', 'score': 0.9994420409202576}],
#  [{'label': 'NEGATIVE', 'score': 0.9986268281936646}],
#  [{'label': 'POSITIVE', 'score': 0.9996618032455444}],
#  [{'label': 'NEGATIVE', 'score': 0.9966118931770325}],
#  [{'label': 'NEGATIVE', 'score': 0.999241828918457}],
#  [{'label': 'NEGATIVE', 'score': 0.9506561756134033}],
#  [{'label': 'POSITIVE', 'score': 0.9998540878295898}],
#  [{'label': 'POSITIVE', 'score': 0.995969295501709}],
#  [{'label': 'POSITIVE', 'score': 0.998981773853302}],
#  [{'label': 'POSITIVE', 'score': 0.999884843826294}],
#  [{'label': 'NEGATIVE', 'score': 0.9990667700767517}],
#  [{'label': 'NEGATIVE', 'score': 0.9992503523826599}],
#  [{'label': 'NEGATIVE', 'score': 0.994745135307312}],
#  [{'label': 'NEGATIVE', 'score': 0.9997709393501282}],
#  [{'label': 'POSITIVE', 'score': 0.9918457865715027}],
#  [{'label': 'POSITIVE', 'score': 0.9997912049293518}],
#  [{'label': 'NEGATIVE', 'score': 0.9955921769142151}],
#  [{'label': 'NEGATIVE', 'score': 0.9931749701499939}],
#  [{'label': 'POSITIVE', 'score': 0.9998593330383301}],
#  [{'label': 'NEGATIVE', 'score': 0.6969515085220337}],
#  [{'label': 'POSITIVE', 'score': 0.9998401403427124}],
#  [{'label': 'POSITIVE', 'score': 0.9997802376747131}],
#  [{'label': 'NEGATIVE', 'score': 0.9915858507156372}],
#  [{'label': 'POSITIVE', 'score': 0.9998569488525391}],
#  [{'label': 'NEGATIVE', 'score': 0.9993510842323303}],
#  [{'label': 'POSITIVE', 'score': 0.9997305274009705}],
#  [{'label': 'NEGATIVE', 'score': 0.9620018601417542}],
#  [{'label': 'POSITIVE', 'score': 0.9998737573623657}],
#  [{'label': 'POSITIVE', 'score': 0.9987196922302246}],
#  [{'label': 'NEGATIVE', 'score': 0.9994814991950989}],
#  [{'label': 'POSITIVE', 'score': 0.9995288848876953}],
#  [{'label': 'POSITIVE', 'score': 0.9998599290847778}],
#  [{'label': 'NEGATIVE', 'score': 0.9997212290763855}],
#  [{'label': 'POSITIVE', 'score': 0.9998866319656372}],
#  [{'label': 'POSITIVE', 'score': 0.9998238682746887}],
#  [{'label': 'NEGATIVE', 'score': 0.9964498281478882}],
#  [{'label': 'NEGATIVE', 'score': 0.9989259839057922}],
#  [{'label': 'POSITIVE', 'score': 0.9998376369476318}],
#  [{'label': 'POSITIVE', 'score': 0.9998526573181152}],
#  [{'label': 'NEGATIVE', 'score': 0.9950616955757141}],
#  [{'label': 'NEGATIVE', 'score': 0.9988824725151062}],
#  [{'label': 'NEGATIVE', 'score': 0.9966216087341309}],
#  [{'label': 'NEGATIVE', 'score': 0.9987646341323853}],
#  [{'label': 'NEGATIVE', 'score': 0.9997290968894958}],
#  [{'label': 'NEGATIVE', 'score': 0.9260266423225403}],
#  [{'label': 'POSITIVE', 'score': 0.999886155128479}],
#  [{'label': 'POSITIVE', 'score': 0.9998626708984375}],
#  [{'label': 'POSITIVE', 'score': 0.9991781115531921}],
#  [{'label': 'POSITIVE', 'score': 0.9998840093612671}],
#  [{'label': 'NEGATIVE', 'score': 0.9998020529747009}],
#  [{'label': 'POSITIVE', 'score': 0.997666597366333}],
#  [{'label': 'POSITIVE', 'score': 0.9989376664161682}],
#  [{'label': 'NEGATIVE', 'score': 0.9998108744621277}],
#  [{'label': 'POSITIVE', 'score': 0.9998749494552612}],
#  [{'label': 'POSITIVE', 'score': 0.9997197985649109}],
#  [{'label': 'POSITIVE', 'score': 0.5226612091064453}],
#  [{'label': 'NEGATIVE', 'score': 0.9986660480499268}],
#  [{'label': 'POSITIVE', 'score': 0.9998568296432495}],
#  [{'label': 'POSITIVE', 'score': 0.9994028806686401}],
#  [{'label': 'POSITIVE', 'score': 0.9998641014099121}],
#  [{'label': 'NEGATIVE', 'score': 0.998547375202179}],
#  [{'label': 'POSITIVE', 'score': 0.9991567134857178}],
#  [{'label': 'POSITIVE', 'score': 0.855980396270752}],
#  [{'label': 'NEGATIVE', 'score': 0.9997785687446594}],
#  [{'label': 'NEGATIVE', 'score': 0.9995934367179871}],
#  [{'label': 'POSITIVE', 'score': 0.9995655417442322}],
#  [{'label': 'POSITIVE', 'score': 0.9998593330383301}],
#  [{'label': 'POSITIVE', 'score': 0.9998237490653992}],
#  [{'label': 'POSITIVE', 'score': 0.9998817443847656}],
#  [{'label': 'NEGATIVE', 'score': 0.997643768787384}],
#  [{'label': 'POSITIVE', 'score': 0.9997561573982239}],
#  [{'label': 'NEGATIVE', 'score': 0.9996885061264038}],
#  [{'label': 'NEGATIVE', 'score': 0.9994970560073853}],
#  [{'label': 'POSITIVE', 'score': 0.999884843826294}],
#  [{'label': 'POSITIVE', 'score': 0.9994320273399353}],
#  [{'label': 'POSITIVE', 'score': 0.9919203519821167}],
#  [{'label': 'NEGATIVE', 'score': 0.9880093932151794}],
#  [{'label': 'NEGATIVE', 'score': 0.9993264675140381}],
#  [{'label': 'POSITIVE', 'score': 0.999862790107727}],
#  [{'label': 'POSITIVE', 'score': 0.5356494188308716}],
#  [{'label': 'POSITIVE', 'score': 0.9735035300254822}],
#  [{'label': 'NEGATIVE', 'score': 0.9997547268867493}],
#  [{'label': 'POSITIVE', 'score': 0.9994015693664551}],
#  [{'label': 'POSITIVE', 'score': 0.9998008608818054}],
#  [{'label': 'NEGATIVE', 'score': 0.9912202954292297}],
#  [{'label': 'POSITIVE', 'score': 0.9998689889907837}],
#  [{'label': 'POSITIVE', 'score': 0.9998600482940674}],
#  [{'label': 'POSITIVE', 'score': 0.9906903505325317}],
#  [{'label': 'POSITIVE', 'score': 0.9997425675392151}],
#  [{'label': 'POSITIVE', 'score': 0.9998632669448853}],
#  [{'label': 'NEGATIVE', 'score': 0.9988806843757629}],
#  [{'label': 'POSITIVE', 'score': 0.9989877343177795}],
#  [{'label': 'POSITIVE', 'score': 0.999887228012085}],
#  [{'label': 'POSITIVE', 'score': 0.9997782111167908}],
#  [{'label': 'NEGATIVE', 'score': 0.9862124919891357}],
#  [{'label': 'NEGATIVE', 'score': 0.9991244673728943}],
#  [{'label': 'NEGATIVE', 'score': 0.9973031282424927}],
#  [{'label': 'NEGATIVE', 'score': 0.994722843170166}],
#  [{'label': 'NEGATIVE', 'score': 0.9998070597648621}],
#  [{'label': 'POSITIVE', 'score': 0.9962618947029114}],
#  [{'label': 'POSITIVE', 'score': 0.9998487234115601}],
#  [{'label': 'POSITIVE', 'score': 0.9997411370277405}],
#  [{'label': 'POSITIVE', 'score': 0.9984003901481628}],
#  [{'label': 'POSITIVE', 'score': 0.9998651742935181}],
#  [{'label': 'POSITIVE', 'score': 0.9993727803230286}],
#  [{'label': 'POSITIVE', 'score': 0.5329704284667969}],
#  [{'label': 'POSITIVE', 'score': 0.9998132586479187}],
#  [{'label': 'NEGATIVE', 'score': 0.9984762072563171}],
#  [{'label': 'POSITIVE', 'score': 0.9979732632637024}],
#  [{'label': 'POSITIVE', 'score': 0.9997274279594421}],
#  [{'label': 'POSITIVE', 'score': 0.9902240633964539}],
#  [{'label': 'NEGATIVE', 'score': 0.9994843006134033}],
#  [{'label': 'NEGATIVE', 'score': 0.9802823066711426}],
#  [{'label': 'POSITIVE', 'score': 0.9998594522476196}],
#  [{'label': 'NEGATIVE', 'score': 0.9959734082221985}],
#  [{'label': 'NEGATIVE', 'score': 0.9783143401145935}],
#  [{'label': 'POSITIVE', 'score': 0.9961646795272827}],
#  [{'label': 'POSITIVE', 'score': 0.9921718835830688}],
#  [{'label': 'POSITIVE', 'score': 0.9997803568840027}],
#  [{'label': 'POSITIVE', 'score': 0.9998773336410522}],
#  [{'label': 'POSITIVE', 'score': 0.9961673617362976}],
#  [{'label': 'POSITIVE', 'score': 0.9993739724159241}],
#  [{'label': 'POSITIVE', 'score': 0.9991500377655029}],
#  [{'label': 'NEGATIVE', 'score': 0.9996991157531738}],
#  [{'label': 'POSITIVE', 'score': 0.9998732805252075}],
#  [{'label': 'NEGATIVE', 'score': 0.9994438290596008}],
#  [{'label': 'POSITIVE', 'score': 0.9998912811279297}],
#  [{'label': 'NEGATIVE', 'score': 0.9997850060462952}],
#  [{'label': 'POSITIVE', 'score': 0.9995015859603882}],
#  [{'label': 'POSITIVE', 'score': 0.9995315074920654}],
#  [{'label': 'NEGATIVE', 'score': 0.9948723912239075}],
#  [{'label': 'POSITIVE', 'score': 0.9770062565803528}],
#  [{'label': 'NEGATIVE', 'score': 0.9657592177391052}],
#  [{'label': 'NEGATIVE', 'score': 0.9802240133285522}],
#  [{'label': 'POSITIVE', 'score': 0.9998799562454224}],
#  [{'label': 'POSITIVE', 'score': 0.9995835423469543}],
#  [{'label': 'POSITIVE', 'score': 0.9869138598442078}],
#  [{'label': 'NEGATIVE', 'score': 0.883816123008728}],
#  [{'label': 'POSITIVE', 'score': 0.9980903267860413}],
#  [{'label': 'POSITIVE', 'score': 0.99803227186203}],
#  [{'label': 'POSITIVE', 'score': 0.9998656511306763}],
#  [{'label': 'POSITIVE', 'score': 0.632914125919342}],
#  [{'label': 'NEGATIVE', 'score': 0.9997106194496155}],
#  [{'label': 'NEGATIVE', 'score': 0.9996209144592285}],
#  [{'label': 'NEGATIVE', 'score': 0.9926458597183228}],
#  [{'label': 'NEGATIVE', 'score': 0.9996325969696045}],
#  [{'label': 'NEGATIVE', 'score': 0.998954176902771}],
#  [{'label': 'POSITIVE', 'score': 0.999869704246521}],
#  [{'label': 'POSITIVE', 'score': 0.9995833039283752}],
#  [{'label': 'NEGATIVE', 'score': 0.9989062547683716}],
#  [{'label': 'NEGATIVE', 'score': 0.9991544485092163}],
#  [{'label': 'POSITIVE', 'score': 0.9998615980148315}],
#  [{'label': 'POSITIVE', 'score': 0.9958069324493408}],
#  [{'label': 'POSITIVE', 'score': 0.9998809099197388}],
#  [{'label': 'POSITIVE', 'score': 0.9219184517860413}],
#  [{'label': 'NEGATIVE', 'score': 0.9995428323745728}],
#  [{'label': 'POSITIVE', 'score': 0.9998815059661865}],
#  [{'label': 'NEGATIVE', 'score': 0.7487496733665466}],
#  [{'label': 'NEGATIVE', 'score': 0.9923062920570374}],
#  [{'label': 'NEGATIVE', 'score': 0.9995248317718506}],
#  [{'label': 'NEGATIVE', 'score': 0.9996684789657593}],
#  [{'label': 'NEGATIVE', 'score': 0.9412465691566467}],
#  [{'label': 'POSITIVE', 'score': 0.9997759461402893}],
#  [{'label': 'POSITIVE', 'score': 0.9640851616859436}],
#  [{'label': 'NEGATIVE', 'score': 0.999782383441925}],
#  [{'label': 'NEGATIVE', 'score': 0.998119056224823}],
#  [{'label': 'POSITIVE', 'score': 0.999758780002594}],
#  [{'label': 'POSITIVE', 'score': 0.9998801946640015}],
#  [{'label': 'POSITIVE', 'score': 0.9996132254600525}],
#  [{'label': 'NEGATIVE', 'score': 0.9988304972648621}],
#  [{'label': 'NEGATIVE', 'score': 0.9987205862998962}],
#  [{'label': 'NEGATIVE', 'score': 0.9751893281936646}],
#  [{'label': 'POSITIVE', 'score': 0.9994174242019653}],
#  [{'label': 'NEGATIVE', 'score': 0.994138240814209}],
#  [{'label': 'POSITIVE', 'score': 0.9998818635940552}],
#  [{'label': 'POSITIVE', 'score': 0.996647298336029}],
#  [{'label': 'NEGATIVE', 'score': 0.99960857629776}],
#  [{'label': 'POSITIVE', 'score': 0.9994418025016785}],
#  [{'label': 'NEGATIVE', 'score': 0.9989711046218872}],
#  [{'label': 'POSITIVE', 'score': 0.9997324347496033}],
#  [{'label': 'POSITIVE', 'score': 0.999512791633606}],
#  [{'label': 'NEGATIVE', 'score': 0.640571117401123}],
#  [{'label': 'NEGATIVE', 'score': 0.9997699856758118}],
#  [{'label': 'NEGATIVE', 'score': 0.9996800422668457}],
#  [{'label': 'POSITIVE', 'score': 0.9971076846122742}],
#  [{'label': 'POSITIVE', 'score': 0.9982936978340149}],
#  [{'label': 'POSITIVE', 'score': 0.9986635446548462}],
#  [{'label': 'POSITIVE', 'score': 0.9982280135154724}],
#  [{'label': 'NEGATIVE', 'score': 0.9998087286949158}],
#  [{'label': 'NEGATIVE', 'score': 0.9985974431037903}],
#  [{'label': 'NEGATIVE', 'score': 0.9988853335380554}],
#  [{'label': 'POSITIVE', 'score': 0.9995930790901184}],
#  [{'label': 'POSITIVE', 'score': 0.9998805522918701}],
#  [{'label': 'POSITIVE', 'score': 0.9065142273902893}],
#  [{'label': 'POSITIVE', 'score': 0.999866247177124}],
#  [{'label': 'POSITIVE', 'score': 0.9998674392700195}],
#  [{'label': 'NEGATIVE', 'score': 0.9993094205856323}],
#  [{'label': 'POSITIVE', 'score': 0.9977973699569702}],
#  [{'label': 'NEGATIVE', 'score': 0.988884687423706}],
#  [{'label': 'NEGATIVE', 'score': 0.9980884194374084}],
#  [{'label': 'NEGATIVE', 'score': 0.9990999698638916}],
#  [{'label': 'NEGATIVE', 'score': 0.9976135492324829}],
#  [{'label': 'NEGATIVE', 'score': 0.9993751645088196}],
#  [{'label': 'POSITIVE', 'score': 0.9985355138778687}],
#  [{'label': 'POSITIVE', 'score': 0.9998722076416016}],
#  [{'label': 'NEGATIVE', 'score': 0.9975287318229675}],
#  [{'label': 'POSITIVE', 'score': 0.997260570526123}],
#  [{'label': 'POSITIVE', 'score': 0.9997650980949402}],
#  [{'label': 'NEGATIVE', 'score': 0.9986439347267151}],
#  [{'label': 'NEGATIVE', 'score': 0.9997884631156921}],
#  [{'label': 'NEGATIVE', 'score': 0.9997894167900085}],
#  [{'label': 'NEGATIVE', 'score': 0.9868096113204956}],
#  [{'label': 'NEGATIVE', 'score': 0.951948881149292}],
#  [{'label': 'POSITIVE', 'score': 0.9998757839202881}],
#  [{'label': 'POSITIVE', 'score': 0.999879002571106}],
#  [{'label': 'POSITIVE', 'score': 0.9723201990127563}],
#  [{'label': 'NEGATIVE', 'score': 0.9454059600830078}],
#  [{'label': 'NEGATIVE', 'score': 0.9817882776260376}],
#  [{'label': 'POSITIVE', 'score': 0.999864935874939}],
#  [{'label': 'POSITIVE', 'score': 0.99985671043396}],
#  [{'label': 'POSITIVE', 'score': 0.9996763467788696}],
#  [{'label': 'NEGATIVE', 'score': 0.998685896396637}],
#  [{'label': 'POSITIVE', 'score': 0.9968183040618896}],
#  [{'label': 'POSITIVE', 'score': 0.6525717973709106}],
#  [{'label': 'POSITIVE', 'score': 0.9996212720870972}],
#  [{'label': 'NEGATIVE', 'score': 0.9959141612052917}],
#  [{'label': 'POSITIVE', 'score': 0.9993220567703247}],
#  [{'label': 'NEGATIVE', 'score': 0.9976416826248169}],
#  [{'label': 'POSITIVE', 'score': 0.9998646974563599}],
#  [{'label': 'POSITIVE', 'score': 0.9998676776885986}],
#  [{'label': 'NEGATIVE', 'score': 0.9995228052139282}],
#  [{'label': 'POSITIVE', 'score': 0.9996414184570312}],
#  [{'label': 'NEGATIVE', 'score': 0.9788045883178711}],
#  [{'label': 'NEGATIVE', 'score': 0.9995146989822388}],
#  [{'label': 'NEGATIVE', 'score': 0.9998056292533875}],
#  [{'label': 'NEGATIVE', 'score': 0.9997978806495667}],
#  [{'label': 'POSITIVE', 'score': 0.9846845865249634}],
#  [{'label': 'POSITIVE', 'score': 0.9998816251754761}],
#  [{'label': 'NEGATIVE', 'score': 0.9948550462722778}],
#  [{'label': 'NEGATIVE', 'score': 0.9997155070304871}],
#  [{'label': 'POSITIVE', 'score': 0.9998781681060791}],
#  [{'label': 'POSITIVE', 'score': 0.9998217225074768}],
#  [{'label': 'NEGATIVE', 'score': 0.9998117089271545}],
#  [{'label': 'POSITIVE', 'score': 0.999797523021698}],
#  [{'label': 'NEGATIVE', 'score': 0.9991074204444885}],
#  [{'label': 'POSITIVE', 'score': 0.8192371129989624}],
#  [{'label': 'NEGATIVE', 'score': 0.8734241127967834}],
#  [{'label': 'NEGATIVE', 'score': 0.9995831847190857}],
#  [{'label': 'POSITIVE', 'score': 0.9998745918273926}],
#  [{'label': 'POSITIVE', 'score': 0.9998470544815063}],
#  [{'label': 'POSITIVE', 'score': 0.9710164070129395}],
#  [{'label': 'POSITIVE', 'score': 0.9998012185096741}],
#  [{'label': 'POSITIVE', 'score': 0.9998708963394165}],
#  [{'label': 'POSITIVE', 'score': 0.9984549283981323}],
#  [{'label': 'POSITIVE', 'score': 0.9996521472930908}],
#  [{'label': 'POSITIVE', 'score': 0.9986981153488159}],
#  [{'label': 'POSITIVE', 'score': 0.9998142123222351}],
#  [{'label': 'NEGATIVE', 'score': 0.9930805563926697}],
#  [{'label': 'NEGATIVE', 'score': 0.9932390451431274}],
#  [{'label': 'NEGATIVE', 'score': 0.9944049119949341}],
#  [{'label': 'POSITIVE', 'score': 0.9987401366233826}],
#  [{'label': 'NEGATIVE', 'score': 0.9884575009346008}],
#  [{'label': 'POSITIVE', 'score': 0.9993770718574524}],
#  [{'label': 'POSITIVE', 'score': 0.9998828172683716}],
#  [{'label': 'POSITIVE', 'score': 0.999883770942688}],
#  [{'label': 'POSITIVE', 'score': 0.9530314803123474}],
#  [{'label': 'NEGATIVE', 'score': 0.9997900128364563}],
#  [{'label': 'POSITIVE', 'score': 0.999885082244873}],
#  [{'label': 'NEGATIVE', 'score': 0.9995235204696655}],
#  [{'label': 'POSITIVE', 'score': 0.9983799457550049}],
#  [{'label': 'NEGATIVE', 'score': 0.9984519481658936}],
#  [{'label': 'POSITIVE', 'score': 0.9998428821563721}],
#  [{'label': 'POSITIVE', 'score': 0.999889612197876}],
#  [{'label': 'POSITIVE', 'score': 0.9996917247772217}],
#  [{'label': 'NEGATIVE', 'score': 0.9997867941856384}],
#  [{'label': 'POSITIVE', 'score': 0.9264823198318481}],
#  [{'label': 'POSITIVE', 'score': 0.9998773336410522}],
#  [{'label': 'POSITIVE', 'score': 0.9998069405555725}],
#  [{'label': 'POSITIVE', 'score': 0.9998657703399658}],
#  [{'label': 'POSITIVE', 'score': 0.9998792409896851}],
#  [{'label': 'NEGATIVE', 'score': 0.9989689588546753}],
#  [{'label': 'POSITIVE', 'score': 0.9997379183769226}],
#  [{'label': 'POSITIVE', 'score': 0.9991656541824341}],
#  [{'label': 'POSITIVE', 'score': 0.9998751878738403}],
#  [{'label': 'NEGATIVE', 'score': 0.9996172189712524}],
#  [{'label': 'NEGATIVE', 'score': 0.9991379976272583}],
#  [{'label': 'NEGATIVE', 'score': 0.9996011853218079}],
#  [{'label': 'NEGATIVE', 'score': 0.993129312992096}],
#  [{'label': 'NEGATIVE', 'score': 0.9997013211250305}],
#  [{'label': 'NEGATIVE', 'score': 0.9997914433479309}],
#  [{'label': 'NEGATIVE', 'score': 0.9988387227058411}],
#  [{'label': 'POSITIVE', 'score': 0.9998613595962524}],
#  [{'label': 'POSITIVE', 'score': 0.9992169141769409}],
#  [{'label': 'POSITIVE', 'score': 0.99882572889328}],
#  [{'label': 'POSITIVE', 'score': 0.552712619304657}],
#  [{'label': 'POSITIVE', 'score': 0.9998786449432373}],
#  [{'label': 'NEGATIVE', 'score': 0.9203009009361267}],
#  [{'label': 'POSITIVE', 'score': 0.9993745684623718}],
#  [{'label': 'NEGATIVE', 'score': 0.999160885810852}],
#  [{'label': 'POSITIVE', 'score': 0.9998438358306885}],
#  [{'label': 'NEGATIVE', 'score': 0.9994237422943115}],
#  [{'label': 'POSITIVE', 'score': 0.9996752738952637}],
#  [{'label': 'NEGATIVE', 'score': 0.9893602132797241}],
#  [{'label': 'POSITIVE', 'score': 0.9995763897895813}],
#  [{'label': 'POSITIVE', 'score': 0.99951171875}],
#  [{'label': 'POSITIVE', 'score': 0.9998769760131836}],
#  [{'label': 'NEGATIVE', 'score': 0.9994650483131409}],
#  [{'label': 'POSITIVE', 'score': 0.9778463244438171}],
#  [{'label': 'NEGATIVE', 'score': 0.9992007613182068}],
#  [{'label': 'POSITIVE', 'score': 0.9998799562454224}],
#  [{'label': 'POSITIVE', 'score': 0.9995535016059875}],
#  [{'label': 'POSITIVE', 'score': 0.9998817443847656}],
#  [{'label': 'POSITIVE', 'score': 0.9990347623825073}],
#  [{'label': 'POSITIVE', 'score': 0.9998632669448853}],
#  [{'label': 'POSITIVE', 'score': 0.9998863935470581}],
#  [{'label': 'POSITIVE', 'score': 0.8747490644454956}],
#  [{'label': 'NEGATIVE', 'score': 0.9190545678138733}],
#  [{'label': 'POSITIVE', 'score': 0.9994366765022278}],
#  [{'label': 'POSITIVE', 'score': 0.9996894598007202}],
#  [{'label': 'NEGATIVE', 'score': 0.9963951706886292}],
#  [{'label': 'POSITIVE', 'score': 0.9968903660774231}],
#  [{'label': 'POSITIVE', 'score': 0.9997512698173523}],
#  [{'label': 'POSITIVE', 'score': 0.9998387098312378}],
#  [{'label': 'POSITIVE', 'score': 0.9899517893791199}],
#  [{'label': 'NEGATIVE', 'score': 0.9967079162597656}],
#  [{'label': 'NEGATIVE', 'score': 0.9996849298477173}],
#  [{'label': 'POSITIVE', 'score': 0.9985792636871338}],
#  [{'label': 'POSITIVE', 'score': 0.9997400641441345}],
#  [{'label': 'POSITIVE', 'score': 0.9993813037872314}],
#  [{'label': 'POSITIVE', 'score': 0.9992749094963074}],
#  [{'label': 'NEGATIVE', 'score': 0.9980278611183167}],
#  [{'label': 'NEGATIVE', 'score': 0.9997758269309998}],
#  [{'label': 'NEGATIVE', 'score': 0.9931684732437134}],
#  [{'label': 'NEGATIVE', 'score': 0.9982795715332031}],
#  [{'label': 'POSITIVE', 'score': 0.9997977614402771}],
#  [{'label': 'POSITIVE', 'score': 0.9993047714233398}],
#  [{'label': 'POSITIVE', 'score': 0.9944146871566772}],
#  [{'label': 'NEGATIVE', 'score': 0.9825733304023743}],
#  [{'label': 'POSITIVE', 'score': 0.9998902082443237}],
#  [{'label': 'POSITIVE', 'score': 0.9997839331626892}],
#  [{'label': 'NEGATIVE', 'score': 0.9754804372787476}],
#  [{'label': 'POSITIVE', 'score': 0.999760091304779}],
#  [{'label': 'POSITIVE', 'score': 0.9997444748878479}],
#  [{'label': 'NEGATIVE', 'score': 0.969474196434021}],
#  [{'label': 'POSITIVE', 'score': 0.9998025298118591}],
#  [{'label': 'NEGATIVE', 'score': 0.9989467263221741}],
#  [{'label': 'POSITIVE', 'score': 0.9998687505722046}],
#  [{'label': 'POSITIVE', 'score': 0.9997511506080627}],
#  [{'label': 'POSITIVE', 'score': 0.7531846165657043}],
#  [{'label': 'POSITIVE', 'score': 0.9997873902320862}],
#  [{'label': 'NEGATIVE', 'score': 0.9998100399971008}],
#  [{'label': 'POSITIVE', 'score': 0.9903308153152466}],
#  [{'label': 'NEGATIVE', 'score': 0.9943987727165222}],
#  [{'label': 'POSITIVE', 'score': 0.9998728036880493}],
#  [{'label': 'NEGATIVE', 'score': 0.9995942711830139}],
#  [{'label': 'POSITIVE', 'score': 0.9937295913696289}],
#  [{'label': 'POSITIVE', 'score': 0.9998810291290283}],
#  [{'label': 'POSITIVE', 'score': 0.9994614720344543}],
#  [{'label': 'POSITIVE', 'score': 0.9992883801460266}],
#  [{'label': 'NEGATIVE', 'score': 0.9997488856315613}],
#  [{'label': 'POSITIVE', 'score': 0.9998735189437866}],
#  [{'label': 'NEGATIVE', 'score': 0.9996681213378906}],
#  [{'label': 'NEGATIVE', 'score': 0.999286949634552}],
#  [{'label': 'POSITIVE', 'score': 0.9998847246170044}],
#  [{'label': 'NEGATIVE', 'score': 0.9994658827781677}],
#  [{'label': 'POSITIVE', 'score': 0.9997010827064514}],
#  [{'label': 'NEGATIVE', 'score': 0.9995668530464172}],
#  [{'label': 'NEGATIVE', 'score': 0.999799907207489}],
#  [{'label': 'NEGATIVE', 'score': 0.9997664093971252}],
#  [{'label': 'POSITIVE', 'score': 0.999606192111969}],
#  [{'label': 'POSITIVE', 'score': 0.9997374415397644}],
#  [{'label': 'POSITIVE', 'score': 0.998256504535675}],
#  [{'label': 'NEGATIVE', 'score': 0.9987818598747253}],
#  [{'label': 'POSITIVE', 'score': 0.9992712140083313}],
#  [{'label': 'POSITIVE', 'score': 0.9984416365623474}],
#  [{'label': 'NEGATIVE', 'score': 0.9995192289352417}],
#  [{'label': 'POSITIVE', 'score': 0.9998472929000854}],
#  [{'label': 'POSITIVE', 'score': 0.9998511075973511}],
#  [{'label': 'POSITIVE', 'score': 0.9998786449432373}],
#  [{'label': 'POSITIVE', 'score': 0.9871366024017334}],
#  [{'label': 'POSITIVE', 'score': 0.9925946593284607}],
#  [{'label': 'NEGATIVE', 'score': 0.9997895359992981}],
#  [{'label': 'POSITIVE', 'score': 0.9998444318771362}],
#  [{'label': 'NEGATIVE', 'score': 0.9993577599525452}],
#  [{'label': 'POSITIVE', 'score': 0.9996857643127441}],
#  [{'label': 'POSITIVE', 'score': 0.9998780488967896}],
#  [{'label': 'POSITIVE', 'score': 0.9998741149902344}],
#  [{'label': 'NEGATIVE', 'score': 0.9994602799415588}],
#  [{'label': 'POSITIVE', 'score': 0.9998471736907959}],
#  [{'label': 'NEGATIVE', 'score': 0.997793436050415}],
#  [{'label': 'POSITIVE', 'score': 0.9995749592781067}],
#  [{'label': 'NEGATIVE', 'score': 0.999186098575592}],
#  [{'label': 'POSITIVE', 'score': 0.9998637437820435}],
#  [{'label': 'POSITIVE', 'score': 0.9998871088027954}],
#  [{'label': 'NEGATIVE', 'score': 0.9997722506523132}],
#  [{'label': 'NEGATIVE', 'score': 0.9725359678268433}],
#  [{'label': 'NEGATIVE', 'score': 0.999153733253479}],
#  [{'label': 'POSITIVE', 'score': 0.9976971745491028}],
#  [{'label': 'POSITIVE', 'score': 0.9997830986976624}],
#  [{'label': 'NEGATIVE', 'score': 0.9993190765380859}],
#  [{'label': 'NEGATIVE', 'score': 0.9994530081748962}],
#  [{'label': 'NEGATIVE', 'score': 0.9997931122779846}],
#  [{'label': 'POSITIVE', 'score': 0.9996612071990967}],
#  [{'label': 'POSITIVE', 'score': 0.9998842477798462}],
#  [{'label': 'POSITIVE', 'score': 0.9955464601516724}],
#  [{'label': 'NEGATIVE', 'score': 0.9991908669471741}],
#  [{'label': 'POSITIVE', 'score': 0.9940319657325745}],
#  [{'label': 'NEGATIVE', 'score': 0.9986812472343445}],
#  [{'label': 'NEGATIVE', 'score': 0.9995730519294739}],
#  [{'label': 'NEGATIVE', 'score': 0.9951159954071045}],
#  [{'label': 'POSITIVE', 'score': 0.9884368777275085}],
#  [{'label': 'POSITIVE', 'score': 0.9911060929298401}],
#  [{'label': 'POSITIVE', 'score': 0.9976902008056641}],
#  [{'label': 'NEGATIVE', 'score': 0.9982789754867554}],
#  [{'label': 'NEGATIVE', 'score': 0.9651179313659668}],
#  [{'label': 'NEGATIVE', 'score': 0.9993470311164856}],
#  [{'label': 'NEGATIVE', 'score': 0.9984356760978699}],
#  [{'label': 'POSITIVE', 'score': 0.9968408346176147}],
#  [{'label': 'NEGATIVE', 'score': 0.9996274709701538}],
#  [{'label': 'NEGATIVE', 'score': 0.8236676454544067}],
#  [{'label': 'NEGATIVE', 'score': 0.9998062252998352}],
#  [{'label': 'NEGATIVE', 'score': 0.9935892820358276}],
#  [{'label': 'POSITIVE', 'score': 0.9998568296432495}],
#  [{'label': 'POSITIVE', 'score': 0.9998645782470703}],
#  [{'label': 'NEGATIVE', 'score': 0.9989544153213501}],
#  [{'label': 'POSITIVE', 'score': 0.999806821346283}],
#  [{'label': 'POSITIVE', 'score': 0.9812528491020203}],
#  [{'label': 'NEGATIVE', 'score': 0.9992315769195557}],
#  [{'label': 'POSITIVE', 'score': 0.9911980032920837}],
#  [{'label': 'NEGATIVE', 'score': 0.9987578392028809}],
#  [{'label': 'POSITIVE', 'score': 0.9998502731323242}],
#  [{'label': 'POSITIVE', 'score': 0.9997226595878601}],
#  [{'label': 'NEGATIVE', 'score': 0.9928883910179138}],
#  [{'label': 'NEGATIVE', 'score': 0.9994638562202454}],
#  [{'label': 'NEGATIVE', 'score': 0.999721348285675}],
#  [{'label': 'NEGATIVE', 'score': 0.9862124919891357}],
#  [{'label': 'POSITIVE', 'score': 0.9998192191123962}],
#  [{'label': 'NEGATIVE', 'score': 0.9997475743293762}],
#  [{'label': 'NEGATIVE', 'score': 0.9979031085968018}],
#  [{'label': 'POSITIVE', 'score': 0.9989292025566101}],
#  [{'label': 'NEGATIVE', 'score': 0.999153733253479}],
#  [{'label': 'POSITIVE', 'score': 0.9998822212219238}],
#  [{'label': 'POSITIVE', 'score': 0.9998440742492676}],
#  [{'label': 'NEGATIVE', 'score': 0.9996583461761475}],
#  [{'label': 'POSITIVE', 'score': 0.994602382183075}],
#  [{'label': 'POSITIVE', 'score': 0.9998475313186646}],
#  [{'label': 'POSITIVE', 'score': 0.9994691014289856}],
#  [{'label': 'NEGATIVE', 'score': 0.9980649352073669}],
#  [{'label': 'NEGATIVE', 'score': 0.9998061060905457}],
#  [{'label': 'POSITIVE', 'score': 0.9998788833618164}],
#  [{'label': 'POSITIVE', 'score': 0.9995627999305725}],
#  [{'label': 'NEGATIVE', 'score': 0.9785634279251099}],
#  [{'label': 'POSITIVE', 'score': 0.9997788071632385}],
#  [{'label': 'POSITIVE', 'score': 0.999756395816803}],
#  [{'label': 'POSITIVE', 'score': 0.9993768334388733}],
#  [{'label': 'POSITIVE', 'score': 0.9998745918273926}],
#  [{'label': 'POSITIVE', 'score': 0.9995040893554688}],
#  [{'label': 'POSITIVE', 'score': 0.9998522996902466}],
#  [{'label': 'NEGATIVE', 'score': 0.9992669224739075}],
#  [{'label': 'NEGATIVE', 'score': 0.9952322840690613}],
#  [{'label': 'NEGATIVE', 'score': 0.9997856020927429}],
#  [{'label': 'POSITIVE', 'score': 0.9998880624771118}],
#  [{'label': 'POSITIVE', 'score': 0.9998759031295776}],
#  [{'label': 'NEGATIVE', 'score': 0.9855483174324036}],
#  [{'label': 'NEGATIVE', 'score': 0.9989132881164551}],
#  [{'label': 'NEGATIVE', 'score': 0.9994558691978455}],
#  [{'label': 'POSITIVE', 'score': 0.9930151700973511}],
#  [{'label': 'POSITIVE', 'score': 0.9998570680618286}],
#  [{'label': 'NEGATIVE', 'score': 0.9993776679039001}],
#  [{'label': 'NEGATIVE', 'score': 0.9636123776435852}],
#  [{'label': 'NEGATIVE', 'score': 0.9996720552444458}],
#  [{'label': 'POSITIVE', 'score': 0.9998729228973389}],
#  [{'label': 'NEGATIVE', 'score': 0.9655412435531616}],
#  [{'label': 'POSITIVE', 'score': 0.8194071054458618}],
#  [{'label': 'NEGATIVE', 'score': 0.9995784163475037}],
#  [{'label': 'NEGATIVE', 'score': 0.9997698664665222}],
#  [{'label': 'NEGATIVE', 'score': 0.8652244210243225}],
#  [{'label': 'NEGATIVE', 'score': 0.599500834941864}],
#  [{'label': 'NEGATIVE', 'score': 0.9996083378791809}],
#  [{'label': 'POSITIVE', 'score': 0.9986189603805542}],
#  [{'label': 'POSITIVE', 'score': 0.9994778037071228}],
#  [{'label': 'NEGATIVE', 'score': 0.9914175271987915}],
#  [{'label': 'NEGATIVE', 'score': 0.9997681975364685}],
#  [{'label': 'NEGATIVE', 'score': 0.9449999928474426}],
#  [{'label': 'POSITIVE', 'score': 0.9997391104698181}],
#  [{'label': 'POSITIVE', 'score': 0.9998461008071899}],
#  [{'label': 'POSITIVE', 'score': 0.999845027923584}],
#  [{'label': 'NEGATIVE', 'score': 0.9980473518371582}],
#  [{'label': 'POSITIVE', 'score': 0.9998824596405029}],
#  [{'label': 'NEGATIVE', 'score': 0.9997208714485168}],
#  [{'label': 'POSITIVE', 'score': 0.999294638633728}],
#  [{'label': 'NEGATIVE', 'score': 0.9984694123268127}],
#  [{'label': 'NEGATIVE', 'score': 0.9997001886367798}],
#  [{'label': 'NEGATIVE', 'score': 0.9997081160545349}],
#  [{'label': 'NEGATIVE', 'score': 0.9996774196624756}],
#  [{'label': 'NEGATIVE', 'score': 0.9980530738830566}],
#  [{'label': 'POSITIVE', 'score': 0.9998327493667603}],
#  [{'label': 'NEGATIVE', 'score': 0.9981312155723572}],
#  [{'label': 'POSITIVE', 'score': 0.998734176158905}],
#  [{'label': 'NEGATIVE', 'score': 0.9992833733558655}],
#  [{'label': 'NEGATIVE', 'score': 0.9994947910308838}],
#  [{'label': 'NEGATIVE', 'score': 0.998630166053772}],
#  [{'label': 'NEGATIVE', 'score': 0.9993057250976562}],
#  [{'label': 'NEGATIVE', 'score': 0.9996675252914429}],
#  [{'label': 'NEGATIVE', 'score': 0.9920111298561096}],
#  [{'label': 'NEGATIVE', 'score': 0.9994601607322693}],
#  [{'label': 'NEGATIVE', 'score': 0.9992775321006775}],
#  [{'label': 'NEGATIVE', 'score': 0.9538028240203857}],
#  [{'label': 'NEGATIVE', 'score': 0.9995549321174622}],
#  [{'label': 'NEGATIVE', 'score': 0.9973980188369751}],
#  [{'label': 'NEGATIVE', 'score': 0.9996271133422852}],
#  [{'label': 'POSITIVE', 'score': 0.9982280135154724}],
#  [{'label': 'NEGATIVE', 'score': 0.9976922273635864}],
#  [{'label': 'NEGATIVE', 'score': 0.9996803998947144}],
#  [{'label': 'POSITIVE', 'score': 0.9966204166412354}],
#  [{'label': 'NEGATIVE', 'score': 0.9997596144676208}],
#  [{'label': 'NEGATIVE', 'score': 0.9605383276939392}],
#  [{'label': 'NEGATIVE', 'score': 0.9994693398475647}],
#  [{'label': 'NEGATIVE', 'score': 0.9998063445091248}],
#  [{'label': 'NEGATIVE', 'score': 0.9995527863502502}],
#  [{'label': 'NEGATIVE', 'score': 0.8794859051704407}],
#  [{'label': 'NEGATIVE', 'score': 0.9984833598136902}],
#  [{'label': 'NEGATIVE', 'score': 0.9964554309844971}],
#  [{'label': 'NEGATIVE', 'score': 0.9993163347244263}],
#  [{'label': 'NEGATIVE', 'score': 0.9997969269752502}],
#  [{'label': 'NEGATIVE', 'score': 0.9989134073257446}],
#  [{'label': 'NEGATIVE', 'score': 0.9837972521781921}],
#  [{'label': 'NEGATIVE', 'score': 0.9985664486885071}],
#  [{'label': 'NEGATIVE', 'score': 0.991496741771698}],
#  [{'label': 'NEGATIVE', 'score': 0.9997623562812805}],
#  [{'label': 'NEGATIVE', 'score': 0.994139552116394}],
#  [{'label': 'NEGATIVE', 'score': 0.9997627139091492}],
#  [{'label': 'NEGATIVE', 'score': 0.9997759461402893}],
#  [{'label': 'NEGATIVE', 'score': 0.9997263550758362}],
#  [{'label': 'NEGATIVE', 'score': 0.9997311234474182}],
#  [{'label': 'NEGATIVE', 'score': 0.9996603727340698}],
#  [{'label': 'NEGATIVE', 'score': 0.9997609257698059}],
#  [{'label': 'NEGATIVE', 'score': 0.9995574355125427}],
#  [{'label': 'NEGATIVE', 'score': 0.7374904155731201}],
#  [{'label': 'POSITIVE', 'score': 0.7880740761756897}],
#  [{'label': 'NEGATIVE', 'score': 0.9996242523193359}],
#  [{'label': 'POSITIVE', 'score': 0.7760815024375916}],
#  [{'label': 'NEGATIVE', 'score': 0.9996953010559082}],
#  [{'label': 'NEGATIVE', 'score': 0.9995635151863098}],
#  [{'label': 'NEGATIVE', 'score': 0.9990009665489197}],
#  [{'label': 'NEGATIVE', 'score': 0.9992522597312927}],
#  [{'label': 'NEGATIVE', 'score': 0.999769389629364}],
#  [{'label': 'POSITIVE', 'score': 0.9690213799476624}],
#  [{'label': 'NEGATIVE', 'score': 0.998808741569519}],
#  [{'label': 'NEGATIVE', 'score': 0.9993009567260742}],
#  [{'label': 'NEGATIVE', 'score': 0.9964166879653931}],
#  [{'label': 'NEGATIVE', 'score': 0.9992386102676392}],
#  [{'label': 'NEGATIVE', 'score': 0.9996861219406128}],
#  [{'label': 'NEGATIVE', 'score': 0.9996036887168884}],
#  [{'label': 'NEGATIVE', 'score': 0.9967670440673828}],
#  [{'label': 'NEGATIVE', 'score': 0.996630847454071}],
#  [{'label': 'NEGATIVE', 'score': 0.9983957409858704}],
#  [{'label': 'NEGATIVE', 'score': 0.9991554021835327}],
#  [{'label': 'NEGATIVE', 'score': 0.9915347695350647}],
#  [{'label': 'NEGATIVE', 'score': 0.9977812170982361}],
#  [{'label': 'NEGATIVE', 'score': 0.995206892490387}],
#  [{'label': 'NEGATIVE', 'score': 0.9983991980552673}],
#  [{'label': 'NEGATIVE', 'score': 0.9995400905609131}],
#  [{'label': 'NEGATIVE', 'score': 0.9997779726982117}],
#  [{'label': 'NEGATIVE', 'score': 0.9996596574783325}],
#  [{'label': 'POSITIVE', 'score': 0.9921607375144958}],
#  [{'label': 'NEGATIVE', 'score': 0.9983580708503723}],
#  [{'label': 'NEGATIVE', 'score': 0.9993917942047119}],
#  [{'label': 'NEGATIVE', 'score': 0.9995794892311096}],
#  [{'label': 'POSITIVE', 'score': 0.9996180534362793}],
#  [{'label': 'NEGATIVE', 'score': 0.9996875524520874}],
#  [{'label': 'NEGATIVE', 'score': 0.9903299808502197}],
#  [{'label': 'NEGATIVE', 'score': 0.9038734436035156}],
#  [{'label': 'NEGATIVE', 'score': 0.9997519850730896}],
#  [{'label': 'NEGATIVE', 'score': 0.9994367957115173}],
#  [{'label': 'NEGATIVE', 'score': 0.9994077682495117}],
#  [{'label': 'NEGATIVE', 'score': 0.9998095631599426}],
#  [{'label': 'POSITIVE', 'score': 0.9998698234558105}],
#  [{'label': 'NEGATIVE', 'score': 0.9990860223770142}],
#  [{'label': 'NEGATIVE', 'score': 0.9998032450675964}],
#  [{'label': 'NEGATIVE', 'score': 0.9965384006500244}],
#  [{'label': 'POSITIVE', 'score': 0.8802096843719482}],
#  [{'label': 'NEGATIVE', 'score': 0.9997785687446594}],
#  [{'label': 'NEGATIVE', 'score': 0.999640703201294}],
#  [{'label': 'NEGATIVE', 'score': 0.9997673630714417}],
#  [{'label': 'NEGATIVE', 'score': 0.9996520280838013}],
#  [{'label': 'NEGATIVE', 'score': 0.9991601705551147}],
#  [{'label': 'NEGATIVE', 'score': 0.9989193677902222}],
#  [{'label': 'NEGATIVE', 'score': 0.987152636051178}]]
